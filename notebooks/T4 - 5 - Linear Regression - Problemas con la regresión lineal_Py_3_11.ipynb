# %% [markdown]
# # El tratamiento de las variables categóricas

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("../datasets/ecom-expense/Ecom Expense.csv")

# %%
df.head()
# Out:
#   Transaction ID  Age    Items   Monthly Income  Transaction Time  Record  \
# 0         TXN001    42       10            7313        627.668127       5
# 1         TXN002    24        8           17747        126.904567       3
# 2         TXN003    47       11           22845        873.469701       2
# 3         TXN004    50       11           18552        380.219428       7
# 4         TXN005    60        2           14439        403.374223       2
#
#    Gender City Tier  Total Spend
# 0  Female    Tier 1  4198.385084
# 1  Female    Tier 2  4134.976648
# 2    Male    Tier 2  5166.614455
# 3  Female    Tier 1  7784.447676
# 4  Female    Tier 2  3254.160485

# %%
dummy_gender = pd.get_dummies(df["Gender"], prefix = "Gender")
dummy_city_tier = pd.get_dummies(df["City Tier"], prefix = "City")

# %%
dummy_gender.head()
# Out:
#    Gender_Female  Gender_Male
# 0           True        False
# 1           True        False
# 2          False         True
# 3           True        False
# 4           True        False

# %%
dummy_city_tier.head()
# Out:
#    City_Tier 1  City_Tier 2  City_Tier 3
# 0         True        False        False
# 1        False         True        False
# 2        False         True        False
# 3         True        False        False
# 4        False         True        False

# %%
column_names = df.columns.values.tolist()
column_names
# Out:
# ['Transaction ID',
#  'Age ',
#  ' Items ',
#  'Monthly Income',
#  'Transaction Time',
#  'Record',
#  'Gender',
#  'City Tier',
#  'Total Spend']

# %%
df_new = df[column_names].join(dummy_gender)
column_names = df_new.columns.values.tolist()
df_new.head()
# Out:
#   Transaction ID  Age    Items   Monthly Income  Transaction Time  Record  \
# 0         TXN001    42       10            7313        627.668127       5
# 1         TXN002    24        8           17747        126.904567       3
# 2         TXN003    47       11           22845        873.469701       2
# 3         TXN004    50       11           18552        380.219428       7
# 4         TXN005    60        2           14439        403.374223       2
#
#    Gender City Tier  Total Spend  Gender_Female  Gender_Male
# 0  Female    Tier 1  4198.385084           True        False
# 1  Female    Tier 2  4134.976648           True        False
# 2    Male    Tier 2  5166.614455          False         True
# 3  Female    Tier 1  7784.447676           True        False
# 4  Female    Tier 2  3254.160485           True        False

# %%
df_new = df_new[column_names].join(dummy_city_tier)
df_new.head()
# Out:
#   Transaction ID  Age    Items   Monthly Income  Transaction Time  Record  \
# 0         TXN001    42       10            7313        627.668127       5
# 1         TXN002    24        8           17747        126.904567       3
# 2         TXN003    47       11           22845        873.469701       2
# 3         TXN004    50       11           18552        380.219428       7
# 4         TXN005    60        2           14439        403.374223       2
#
#    Gender City Tier  Total Spend  Gender_Female  Gender_Male  City_Tier 1  \
# 0  Female    Tier 1  4198.385084           True        False         True
# 1  Female    Tier 2  4134.976648           True        False        False
# 2    Male    Tier 2  5166.614455          False         True        False
# 3  Female    Tier 1  7784.447676           True        False         True
# 4  Female    Tier 2  3254.160485           True        False        False
#
#    City_Tier 2  City_Tier 3
# 0        False        False
# 1         True        False
# 2         True        False
# 3        False        False
# 4         True        False

# %%
feature_cols = ["Monthly Income", "Transaction Time", 
                "Gender_Female", "Gender_Male", 
                "City_Tier 1", "City_Tier 2", "City_Tier 3",
                "Record"]

# %%
X = df_new[feature_cols]
Y = df_new["Total Spend"]

# %%
lm = LinearRegression()
lm.fit(X,Y)
# Out:
# LinearRegression()

# %%
print(lm.intercept_)
print(lm.coef_)
# Out:
# -79.41713030137453
# [ 1.47538980e-01  1.54946125e-01 -1.31025013e+02  1.31025013e+02
#   7.67643260e+01  5.51389743e+01 -1.31903300e+02  7.72233446e+02]

# %%
list(zip(feature_cols, lm.coef_))
# Out:
# [('Monthly Income', 0.14753898049205738),
#  ('Transaction Time', 0.15494612549589615),
#  ('Gender_Female', -131.0250132555463),
#  ('Gender_Male', 131.02501325554596),
#  ('City_Tier 1', 76.76432601049517),
#  ('City_Tier 2', 55.13897430923249),
#  ('City_Tier 3', -131.90330031972775),
#  ('Record', 772.233445744565)]

# %%
lm.score(X,Y)
# Out:
# 0.9179923586131016

# %% [markdown]
# El modelo puede ser escrito como:
# * Total_Spend = -79.41713030137362 + 'Monthly Income'* 0.14753898049205738 + 'Transaction Time'* 0.15494612549589545+'Gender_Female'* -131.02501325554567 + 'Gender_Male'* 131.0250132555456+'City_Tier 1'* 76.76432601049527 + 'City_Tier 2'* 55.138974309232474 + 'City_Tier 3'* -131.9033003197278+'Record'* 772.2334457445648
#     * Si es hombre y vive en CT1: Total_Spend = 128.37220896466724 + 'Monthly Income'* 0.14753898049205738 + 'Transaction Time'* 0.15494612549589545+'Record'* 772.2334457445648
#     * Si es hombre y vive en CT2: Total_Spend = 106.74685726340445 + 'Monthly Income'* 0.14753898049205738 + 'Transaction Time'* 0.15494612549589545 +'Record'* 772.2334457445648
#     * Si es hombre y vive en CT3: Total_Spend = -80.29541736555583 + 'Monthly Income'* 0.14753898049205738 + 'Transaction Time'* 0.15494612549589545+'Record'* 772.2334457445648
#     * Si es mujer y vive en CT1: Total_Spend = -79.41713030137362 + 'Monthly Income'* 0.14753898049205738 + 'Transaction Time'* 0.15494612549589545 - 131.0250132555456+ 76.76432601049527 +'Record'* 772.2334457445648
#     * Si es mujer y vive en CT2: Total_Spend = -79.41713030137362 + 'Monthly Income'* 0.14753898049205738 + 'Transaction Time'* 0.15494612549589545 - 131.0250132555456+ 55.138974309232474  +'Record'* 772.2334457445648
#     * Si es mujer y vive en CT3: Total_Spend = -79.41713030137362 + 'Monthly Income'* 0.14753898049205738 + 'Transaction Time'* 0.15494612549589545 - 131.0250132555456-131.9033003197278 +'Record'* 772.2334457445648

# %%
 -79.41713030137362 + 131.0250132555456-131.9033003197278
# Out:
# -80.29541736555583

# %%
df_new["prediction"] = -79.41713030137362 + df_new['Monthly Income']*0.14753898049205738 + df_new['Transaction Time']* 0.15494612549589545+ df_new['Gender_Female'] * (-131.02501325554567) + df_new['Gender_Male'] * 131.0250132555456+ df_new['City_Tier 1']* 76.76432601049527 +  df_new['City_Tier 2']* 55.138974309232474 + df_new['City_Tier 3']* (-131.9033003197278)+ df_new['Record']* 772.2334457445648

# %%
df_new.head()
# Out:
#   Transaction ID  Age    Items   Monthly Income  Transaction Time  Record  \
# 0         TXN001    42       10            7313        627.668127       5
# 1         TXN002    24        8           17747        126.904567       3
# 2         TXN003    47       11           22845        873.469701       2
# 3         TXN004    50       11           18552        380.219428       7
# 4         TXN005    60        2           14439        403.374223       2
#
#    Gender City Tier  Total Spend  Gender_Female  Gender_Male  City_Tier 1  \
# 0  Female    Tier 1  4198.385084           True        False         True
# 1  Female    Tier 2  4134.976648           True        False        False
# 2    Male    Tier 2  5166.614455          False         True        False
# 3  Female    Tier 1  7784.447676           True        False         True
# 4  Female    Tier 2  3254.160485           True        False        False
#
#    City_Tier 2  City_Tier 3   prediction
# 0        False        False  4903.696720
# 1         True        False  4799.434826
# 2         True        False  5157.082504
# 3        False        False  8068.012996
# 4         True        False  3581.980335

# %%
SSD = np.sum((df_new["prediction"] - df_new["Total Spend"])**2)

# %%
SSD
# Out:
# 1517733985.340816

# %%
RSE = np.sqrt(SSD/(len(df_new)-len(feature_cols)-1))

# %%
RSE
# Out:
# 803.1318809818165

# %%
sales_mean=np.mean(df_new["Total Spend"])

# %%
sales_mean
# Out:
# 6163.176415976715

# %%
error = RSE/sales_mean

# %%
error*100
# Out:
# 13.03113568029416

# %% [markdown]
# ## Eliminar variables dummy redundantes

# %%
dummy_gender = pd.get_dummies(df["Gender"], prefix="Gender").iloc[:,1:]
dummy_gender.head()
# Out:
#    Gender_Male
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False

# %%
dummy_city_tier = pd.get_dummies(df["City Tier"], prefix="City").iloc[:,1:]
dummy_city_tier.head()
# Out:
#    City_Tier 2  City_Tier 3
# 0        False        False
# 1         True        False
# 2         True        False
# 3        False        False
# 4         True        False

# %%
column_names = df.columns.values.tolist()
df_new = df[column_names].join(dummy_gender)
column_names = df_new.columns.values.tolist()
df_new = df_new[column_names].join(dummy_city_tier)
df_new.head()
# Out:
#   Transaction ID  Age    Items   Monthly Income  Transaction Time  Record  \
# 0         TXN001    42       10            7313        627.668127       5
# 1         TXN002    24        8           17747        126.904567       3
# 2         TXN003    47       11           22845        873.469701       2
# 3         TXN004    50       11           18552        380.219428       7
# 4         TXN005    60        2           14439        403.374223       2
#
#    Gender City Tier  Total Spend  Gender_Male  City_Tier 2  City_Tier 3
# 0  Female    Tier 1  4198.385084        False        False        False
# 1  Female    Tier 2  4134.976648        False         True        False
# 2    Male    Tier 2  5166.614455         True         True        False
# 3  Female    Tier 1  7784.447676        False        False        False
# 4  Female    Tier 2  3254.160485        False         True        False

# %%
feature_cols = ["Monthly Income", "Transaction Time", "Gender_Male", "City_Tier 2", "City_Tier 3", "Record"]
X = df_new[feature_cols]
Y = df_new["Total Spend"]
lm = LinearRegression()
lm.fit(X,Y)
# Out:
# LinearRegression()

# %%
print(lm.intercept_)
# Out:
# -133.6778175464251

# %%
list(zip(feature_cols, lm.coef_))
# Out:
# [('Monthly Income', 0.1475389804920574),
#  ('Transaction Time', 0.15494612549589704),
#  ('Gender_Male', 262.0500265110962),
#  ('City_Tier 2', -21.625351701262638),
#  ('City_Tier 3', -208.6676263302234),
#  ('Record', 772.2334457445644)]

# %%
lm.score(X,Y)
# Out:
# 0.9179923586131016

# %% [markdown]
# Coeficientes con todas las variables en el modelo
# * ('Monthly Income', 0.14753898049205738),
# * ('Transaction Time', 0.15494612549589545),
# * ('Gender_Female', -131.02501325554567),
# * ('Gender_Male', 131.0250132555456),
# * ('City_Tier 1', 76.76432601049527),
# * ('City_Tier 2', 55.138974309232474),
# * ('City_Tier 3', -131.9033003197278),
# * ('Record', 772.2334457445648)
#
#  Coeficientes tras enmascarar las variables dummy pertinentes
# * 'Monthly Income', 0.14753898049205744),
# * ('Transaction Time', 0.15494612549589631),
# * ('Gender_Male', 262.05002651109595),
# * ('City_Tier 2', -21.62535170126296),
# * ('City_Tier 3', -208.66762633022324),
# * ('Record', 772.2334457445635)]
#
# Los cambios se reflejan en
# * Gender_Male:
#     * antes -> 131.02,
#     * después -> 262.05 = ( 131.02 - (-131.02))
# * Gender_Female:
#     * antes -> -131.02,
#     * después -> 0
# * CT1:
#     * antes -> 76.76,
#     * después -> 0
# * CT2:
#     * antes -> 55.13,
#     * después -> -21.62 = (55.13 - 76.76)
# * CT3:
#     * antes -> -131.90,
#     * después -> -208.66 = (-131.90 - 76.76)

# %% [markdown]
# # Transformación de variables para conseguir una relación no lineal

# %%
import pandas as pd

# %%
data_auto = pd.read_csv("../datasets/auto/auto-mpg.csv")
data_auto.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model year  origin                   car name
# 0          70       1  chevrolet chevelle malibu
# 1          70       1          buick skylark 320
# 2          70       1         plymouth satellite
# 3          70       1              amc rebel sst
# 4          70       1                ford torino

# %%
data_auto.shape
# Out:
# (406, 9)

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
data_auto["mpg"] = data_auto["mpg"].dropna()
data_auto["horsepower"] = data_auto["horsepower"].dropna()
plt.plot(data_auto["horsepower"], data_auto["mpg"], "ro")
plt.xlabel("Caballos de Potencia")
plt.ylabel("Consumo (millas por galeón)")
plt.title("CV vs MPG")
# Out:
# Text(0.5, 1.0, 'CV vs MPG')

# %% [markdown]
# ### Modelo de regresión lineal
# * mpg = a + b * horsepower

# %%
X = data_auto["horsepower"].fillna(data_auto["horsepower"].mean())
Y = data_auto["mpg"].fillna(data_auto["mpg"].mean())

# %%
X_data = X.values.reshape(-1, 1)

# %%
lm = LinearRegression()
lm.fit(X_data,Y)
# Out:
# LinearRegression()

# %%
type(X)
# Out:
# pandas.core.series.Series

# %%
type(X_data)
# Out:
# numpy.ndarray

# %%
# %matplotlib inline
plt.plot(X,Y, "ro")
plt.plot(X, lm.predict(X_data), color="blue")

# %%
lm.score(X_data, Y)
# Out:
# 0.574653340645025

# %%
SSD = np.sum((Y - lm.predict(X_data))**2)
RSE = np.sqrt(SSD/(len(X_data)-1))
y_mean = np.mean(Y)
error = RSE/y_mean
SSD, RSE, y_mean, error*100
# Out:
# (10315.75196006092, 5.046879480825511, 23.514572864321607, 21.462773361633474)

# %% [markdown]
# ### Modelo de regresión cuadrático
# * mpg = a + b * horsepower^2

# %%
X_data = X**2
X_data = X_data.values.reshape(-1, 1)

# %%
lm = LinearRegression()
lm.fit(X_data, Y)
# Out:
# LinearRegression()

# %%
lm.score(X_data, Y)
# Out:
# 0.4849887034823205

# %%
SSD = np.sum((Y - lm.predict(X_data))**2)
RSE = np.sqrt(SSD/(len(X_data)-1))
y_mean = np.mean(Y)
error = RSE/y_mean
SSD, RSE, y_mean, error*100
# Out:
# (12490.350340501926, 5.553410772769817, 23.514572864321607, 23.616889852998113)

# %% [markdown]
# ### Modelo de regresión  lineal y cuadrático
# * mpg = a + b * horsepower + c * horsepower^2

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn import linear_model

# %%
poly = PolynomialFeatures(degree=2)

# %%
X_data = poly.fit_transform(X.values.reshape(-1, 1))

# %%
lm = linear_model.LinearRegression()
lm.fit(X_data, Y)
# Out:
# LinearRegression()

# %%
lm.score(X_data, Y)
# Out:
# 0.6439066584257469

# %%
lm.intercept_
# Out:
# 55.02619244708036

# %%
lm.coef_
# Out:
# array([ 0.        , -0.43404318,  0.00112615])

# %% [markdown]
# mpg = 55.026 -0.434 * hp + 0.00112615 * hp^2

# %%
def regresion_validation(X_data, Y, Y_pred):
    SSD = np.sum((Y - Y_pred)**2)
    RSE = np.sqrt(SSD/(len(X_data)-1))
    y_mean = np.mean(Y)
    error = RSE/y_mean
    print("SSD: "+str(SSD)+", RSE: " +str(RSE) + ", Y_mean: " +str(y_mean) +", error: " + str(error*100)+ "%")

# %%
for d in range(2,12):
    poly = PolynomialFeatures(degree=d)
    X_data = poly.fit_transform(X.values.reshape(-1, 1))
    lm = linear_model.LinearRegression()
    lm.fit(X_data, Y)
    print("Regresión de grado "+str(d))
    print("R2:" +str(lm.score(X_data, Y)))
    print(lm.intercept_)
    print(lm.coef_)
    regresion_validation(X_data, Y, lm.predict(X_data))
# Out:
# Regresión de grado 2
# R2:0.6439066584257469
# 55.02619244708036
# [ 0.         -0.43404318  0.00112615]
# SSD: 8636.1806435245, RSE: 4.617781158036539, Y_mean: 23.514572864321607, error: 19.637954661906896%
# Regresión de grado 3
# R2:0.6444678885560744
# 58.44877411191699
# [ 0.00000000e+00 -5.27113167e-01  1.89736722e-03 -1.95723195e-06]
# SSD: 8622.56936742855, RSE: 4.614140736300908, Y_mean: 23.514572864321607, error: 19.622473106036686%
# Regresión de grado 4
# R2:0.6467674189704503
# 40.096643844835526
# [ 0.00000000e+00  1.62563541e-01 -7.10892744e-03  4.65580255e-05
#  -9.15840092e-08]
# SSD: 8566.79983249135, RSE: 4.599194731579757, Y_mean: 23.514572864321607, error: 19.558912501268786%
# Regresión de grado 5
# R2:0.6547512491794394
# -40.693856646425715
# [ 0.00000000e+00  4.00021432e+00 -7.54801920e-02  6.19621369e-04
#  -2.36220932e-06  3.41983042e-09]
# SSD: 8373.171387749198, RSE: 4.546921733843868, Y_mean: 23.514572864321607, error: 19.3366120663959%
# Regresión de grado 6
# R2:0.6572874454774987
# -156.96949839320774
# [ 0.00000000e+00  1.07625886e+01 -2.30177959e-01  2.40602862e-03
#  -1.33812708e-05  3.79838889e-08 -4.32621503e-11]
# SSD: 8311.662095605046, RSE: 4.530190112819115, Y_mean: 23.514572864321607, error: 19.26545780337231%
# Regresión de grado 7
# R2:0.6538574284263332
# 14.781731053813573
# [ 0.00000000e+00  1.12335747e-03  4.31552811e-02 -1.25405989e-03
#   1.46300818e-05 -8.50488933e-08  2.45098814e-10 -2.79312977e-13]
# SSD: 8394.848843027161, RSE: 4.552803733375178, Y_mean: 23.514572864321607, error: 19.361626339737157%
# Regresión de grado 8
# R2:0.6512432184890828
# 36.40672411110828
# [ 0.00000000e+00  4.43839509e-07  3.03135402e-06  8.84885519e-05
#  -3.97067216e-06  5.47393614e-08 -3.43825965e-10  1.02689462e-12
#  -1.18561694e-15]
# SSD: 8458.250166844062, RSE: 4.5699637102711455, Y_mean: 23.514572864321607, error: 19.43460226405005%
# Regresión de grado 9
# R2:0.6510536317458637
# 39.46638011148389
# [ 0.00000000e+00 -7.80550515e-09 -1.25156828e-09 -6.48447522e-08
#  -1.77132817e-06  3.55551178e-08 -3.00241169e-10  1.32278866e-12
#  -3.04048227e-15  2.92448720e-18]
# SSD: 8462.848133643496, RSE: 4.571205674396883, Y_mean: 23.514572864321607, error: 19.439883942492195%
# Regresión de grado 10
# R2:0.6523570734251485
# 38.439932514943855
# [ 0.00000000e+00 -1.18975188e-09 -9.30075450e-13 -2.72051405e-11
#  -1.29822322e-09 -3.51557709e-08  8.70013852e-10 -8.86585934e-12
#   4.60157221e-14 -1.20803395e-16  1.27732347e-19]
# SSD: 8431.236315936272, RSE: 4.562660128341386, Y_mean: 23.514572864321607, error: 19.4035424528772%
# Regresión de grado 11
# R2:0.6511673538757514
# 36.407737822566204
# [ 0.00000000e+00 -6.35905528e-12  3.74797301e-15 -4.91817347e-15
#  -3.14729810e-13 -1.49252201e-11 -4.09650144e-10  1.04700305e-11
#  -1.08552737e-13  5.67263304e-16 -1.48811966e-18  1.56362160e-21]
# SSD: 8460.090079104946, RSE: 4.570460732402365, Y_mean: 23.514572864321607, error: 19.43671594110507%

# %%
#print(regresion_validation(lm, X_data, Y))

# %% [markdown]
# # El problema de los outliers

# %%
plt.plot(data_auto["displacement"], data_auto["mpg"], "ro")

# %%
X = data_auto["displacement"].fillna(data_auto["displacement"].mean())
X = X.values.reshape(-1, 1)
Y = data_auto["mpg"].fillna(data_auto["mpg"].mean())

lm = LinearRegression()
lm.fit(X, Y)
# Out:
# LinearRegression()

# %%
lm.score(X,Y)
# Out:
# 0.6261049762826918

# %%
# %matplotlib inline
plt.plot(X,Y, "ro")
plt.plot(X, lm.predict(X), color="blue")

# %%
data_auto[(data_auto["displacement"]>250)&(data_auto["mpg"]>35)]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 395  38.0          6         262.0        85.0    3015          17.0
#
#      model year  origin                           car name
# 395          82       1  oldsmobile cutlass ciera (diesel)

# %%
data_auto[(data_auto["displacement"]>300)&(data_auto["mpg"]>20)]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 258  20.2          8         302.0       139.0    3570          12.8
# 305  23.0          8         350.0       125.0    3900          17.4
# 372  26.6          8         350.0       105.0    3725          19.0
#
#      model year  origin               car name
# 258          78       1   mercury monarch ghia
# 305          79       1      cadillac eldorado
# 372          81       1  oldsmobile cutlass ls

# %%
data_auto_clean = data_auto.drop([395, 258, 305, 372])

# %%
X = data_auto_clean["displacement"].fillna(data_auto_clean["displacement"].mean())
X = X.values.reshape(-1, 1)
Y = data_auto_clean["mpg"].fillna(data_auto_clean["mpg"].mean())

lm = LinearRegression()
lm.fit(X, Y)
# Out:
# LinearRegression()

# %%
lm.score(X,Y)
# Out:
# 0.6466514317531822

# %%
# %matplotlib inline
plt.plot(X,Y, "ro")
plt.plot(X, lm.predict(X), color="blue")
